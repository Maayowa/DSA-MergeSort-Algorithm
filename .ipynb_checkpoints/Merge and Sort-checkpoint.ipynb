# %%
### Intro to List sorting using DSA

# %%
net = list(range(1,25, 3))
random.seed(7)

import random
random.shuffle(net)
print(net)
# Out:
# [19, 22, 7, 13, 1, 10, 4, 16]

# %%
def insertsort(x):
    nums = list(x)
    for i in range(len(nums)):
        cur = nums.pop(i)
        j = i - 1
        
        print("*" * 20, f'{i + 1}th Point of iteration', "*" * 20)
        print("Current number and its index: ", cur, i)
        print(f"\nNumber at index {j} is {nums[j]}.")
        print("--"*30, '\n')
        
        while j >= 0 and nums[j] > cur:
            j -= 1
            print(f"Number at {j+1} indices behind is {nums[j]}.")
            print('\n')
        nums.insert(j+1, cur)
        print('\n\n')
    return nums



f_net = insertsort(net)
# Out:
# ******************** 1th Point of iteration ********************
# Current number and its index:  19 0
#
# Number at index -1 is 16.
# ------------------------------------------------------------
#
#
#
#
# ******************** 2th Point of iteration ********************
# Current number and its index:  22 1
#
# Number at index 0 is 19.
# ------------------------------------------------------------
#
#
#
#
# ******************** 3th Point of iteration ********************
# Current number and its index:  7 2
#
# Number at index 1 is 22.
# ------------------------------------------------------------
#
# Number at 1 indices behind is 19.
#
#
# Number at 0 indices behind is 16.
#
#
#
#
#
# ******************** 4th Point of iteration ********************
# Current number and its index:  13 3
#
# Number at index 2 is 22.
# ------------------------------------------------------------
#
# Number at 2 indices behind is 19.
#
#
# Number at 1 indices behind is 7.
#
#
#
#
#
# ******************** 5th Point of iteration ********************
# Current number and its index:  1 4
#
# Number at index 3 is 22.
# ------------------------------------------------------------
#
# Number at 3 indices behind is 19.
#
#
# Number at 2 indices behind is 13.
#
#
# Number at 1 indices behind is 7.
#
#
# Number at 0 indices behind is 16.
#
#
#
#
#
# ******************** 6th Point of iteration ********************
# Current number and its index:  10 5
#
# Number at index 4 is 22.
# ------------------------------------------------------------
#
# Number at 4 indices behind is 19.
#
#
# Number at 3 indices behind is 13.
#
#
# Number at 2 indices behind is 7.
#
#
#
#
#
# ******************** 7th Point of iteration ********************
# Current number and its index:  4 6
#
# Number at index 5 is 22.
# ------------------------------------------------------------
#
# Number at 5 indices behind is 19.
#
#
# Number at 4 indices behind is 13.
#
#
# Number at 3 indices behind is 10.
#
#
# Number at 2 indices behind is 7.
#
#
# Number at 1 indices behind is 1.
#
#
#
#
#
# ******************** 8th Point of iteration ********************
# Current number and its index:  16 7
#
# Number at index 6 is 22.
# ------------------------------------------------------------
#
# Number at 6 indices behind is 19.
#
#
# Number at 5 indices behind is 13.

# %%
f_net

# Read up Insertion sort on line and chck for its 'English explanation'
# Out:
# [1, 4, 7, 10, 13, 16, 19, 22]

# %% [markdown]
# ## Merge Sort (Divide and conquer Algorithm)

# %%
def mergesort(nums):
    """
    This is the part where the division of the list is done
    """
    # Condition for ending recursion
    if len(nums) < 2:
        return nums
    
    mid = len(nums) // 2
    
    # Splitting list into halves
    
    left = nums[:mid]
    right = nums[mid:]
    
    
    # solving and breaking down lists by recursion
    
    left_sort, right_sort = mergesort(left), mergesort(right)
    
    sorted_nums = merge(left_sort, right_sort)
    
    
    return sorted_nums


def merge(nums1, nums2):
    """
    This is the 'conquer function where smaller lists are merged'
    """
    # Allocating pointers for looping through and sorting the list
    nest_list = []
    i = 0
    j = 0
    
    while i < len(nums1) and j < len(nums2):
        if nums1[i] < nums2[j]:
            nest_list.append(nums1[i])
            i += 1
        else:
            nest_list.append(nums2[j])
            j += 1
            
    # After looping and sorting
    nums1_rem = nums1[i:]
    nums2_rem = nums2[j:]
    
    return nest_list + nums1_rem + nums2_rem

# %%
merge([1,4,7,9,11], [-1, 0, 2, 3, 6, 12])
# Out:
# [-1, 0, 1, 2, 3, 4, 6, 7, 9, 11, 12]

# %%
mergesort(net)
# Out:
# [1, 4, 7, 10, 13, 16, 19, 22]

# %%
new_rand = range(10000)
random.seed(28)

new_rand = random.sample(new_rand, 5000)
new_rand
# Out:
# [1850,
#  2143,
#  8940,
#  9785,
#  2917,
#  3709,
#  2170,
#  7603,
#  6841,
#  3455,
#  3495,
#  2364,
#  6417,
#  2668,
#  2147,
#  9935,
#  3073,
#  3296,
#  455,
#  6668,
#  3930,
#  1139,
#  1556,
#  6887,
#  5153,
#  2120,
#  2889,
#  8297,
#  8515,
#  4434,
#  3810,
#  7355,
#  2153,
#  3277,
#  216,
#  4657,
#  4261,
#  1288,
#  8525,
#  8742,
#  4569,
#  2028,
#  9435,
#  6836,
#  2744,
#  3311,
#  6031,
#  1134,
#  534,
#  7034,
#  7998,
#  6121,
#  2613,
#  6185,
#  4218,
#  6327,
#  8263,
#  2866,
#  3772,
#  2824,
#  5057,
#  9620,
#  3108,
#  8771,
#  6898,
#  508,
#  3639,
#  3238,
#  1006,
#  5281,
#  5878,
#  6530,
#  1741,
#  8177,
#  2440,
#  8167,
#  8535,
#  3375,
#  8923,
#  7344,
#  9313,
#  6988,
#  2609,
#  6835,
#  3991,
#  7627,
#  4822,
#  7661,
#  3790,
#  3867,
#  546,
#  247,
#  7135,
#  6670,
#  9053,
#  4134,
#  7206,
#  2253,
#  8549,
#  8261,
#  58,
#  7456,
#  5988,
#  5895,
#  1397,
#  3597,
#  6615,
#  3218,
#  9120,
#  1681,
#  2152,
#  1938,
#  4854,
#  8369,
#  7325,
#  1181,
#  2505,
#  3182,
#  2799,
#  8536,
#  1424,
#  7389,
#  8296,
#  5234,
#  8289,
#  7902,
#  6408,
#  6568,
#  6555,
#  1126,
#  5404,
#  3952,
#  8694,
#  5603,
#  9425,
#  9434,
#  8519,
#  6141,
#  8607,
#  1452,
#  5459,
#  1537,
#  6499,
#  4764,
#  6421,
#  7552,
#  2234,
#  1491,
#  6558,
#  3992,
#  1013,
#  2179,
#  4983,
#  7890,
#  3327,
#  359,
#  2539,
#  9441,
#  7801,
#  505,
#  7600,
#  275,
#  3961,
#  1165,
#  2011,
#  6700,
#  594,
#  945,
#  4381,
#  7922,
#  5608,
#  5344,
#  6438,
#  5825,
#  3392,
#  570,
#  5744,
#  9432,
#  3159,
#  400,
#  5418,
#  8326,
#  1896,
#  1956,
#  6108,
#  1227,
#  1027,
#  3299,
#  9317,
#  2617,
#  9997,
#  4194,
#  7398,
#  6622,
#  8132,
#  8460,
#  2995,
#  3628,
#  5886,
#  6361,
#  9577,
#  4127,
#  3344,
#  6355,
#  630,
#  4492,
#  8173,
#  8357,
#  3669,
#  6097,
#  5165,
#  4680,
#  4529,
#  9477,
#  6089,
#  8446,
#  2444,
#  7012,
#  5214,
#  575,
#  9011,
#  5374,
#  3603,
#  5239,
#  9595,
#  6389,
#  2714,
#  5452,
#  8770,
#  2631,
#  6081,
#  8098,
#  50,
#  6263,
#  91,
#  574,
#  8695,
#  5212,
#  8683,
#  2044,
#  8064,
#  5095,
#  4119,
#  9745,
#  4240,
#  6697,
#  4468,
#  1925,
#  6353,
#  1347,
#  7816,
#  2653,
#  1038,
#  7419,
#  4811,
#  5425,
#  8596,
#  3949,
#  7461,
#  2950,
#  7432,
#  4297,
#  6176,
#  1257,
#  8309,
#  6945,
#  7755,
#  6230,
#  8898,
#  9730,
#  4566,
#  3550,
#  1658,
#  1735,
#  6678,
#  7185,
#  3236,
#  3307,
#  2733,
#  4455,
#  4137,
#  9603,
#  2183,
#  3676,
#  983,
#  4960,
#  3638,
#  8407,
#  2566,
#  3851,
#  7946,
#  6354,
#  6979,
#  5295,
#  9229,
#  3855,
#  1138,
#  4846,
#  6109,
#  6881,
#  170,
#  4133,
#  6269,
#  1659,
#  6406,
#  4546,
#  3067,
#  991,
#  3931,
#  4987,
#  7712,
#  3762,
#  800,
#  4067,
#  448,
#  2344,
#  2087,
#  3433,
#  5363,
#  6554,
#  4152,
#  1672,
#  1890,
#  8783,
#  3684,
#  1937,
#  3084,
#  9242,
#  616,
#  5517,
#  6824,
#  143,
#  941,
#  4761,
#  4308,
#  9275,
#  8526,
#  4264,
#  7977,
#  9490,
#  6597,
#  4602,
#  5845,
#  9093,
#  7980,
#  2065,
#  4547,
#  1308,
#  5596,
#  4271,
#  333,
#  907,
#  1750,
#  1031,
#  2360,
#  6767,
#  8855,
#  2741,
#  17,
#  7335,
#  4976,
#  9882,
#  9908,
#  6312,
#  9187,
#  5738,
#  3389,
#  5407,
#  6372,
#  8817,
#  4900,
#  5679,
#  3559,
#  1717,
#  5149,
#  5243,
#  8850,
#  711,
#  8737,
#  306,
#  6,
#  858,
#  9027,
#  8422,
#  9635,
#  2985,
#  6589,
#  8701,
#  9205,
#  1384,
#  432,
#  4252,
#  7209,
#  6182,
#  6623,
#  9040,
#  8875,
#  3610,
#  1837,
#  1531,
#  6194,
#  1764,
#  5653,
#  2060,
#  6148,
#  5589,
#  632,
#  1262,
#  9726,
#  1018,
#  1752,
#  2497,
#  4668,
#  2004,
#  8222,
#  4036,
#  6441,
#  8149,
#  6942,
#  1783,
#  5377,
#  2485,
#  4327,
#  2349,
#  3471,
#  4523,
#  6826,
#  2471,
#  212,
#  3285,
#  4190,
#  1930,
#  5406,
#  8735,
#  4451,
#  955,
#  4636,
#  4697,
#  9598,
#  1468,
#  2043,
#  3140,
#  8577,
#  2168,
#  249,
#  7732,
#  342,
#  5717,
#  5302,
#  158,
#  8551,
#  3329,
#  2122,
#  6722,
#  2810,
#  1795,
#  7726,
#  9237,
#  5370,
#  9357,
#  5433,
#  2025,
#  744,
#  7640,
#  9169,
#  1480,
#  2626,
#  447,
#  1036,
#  5821,
#  430,
#  8587,
#  732,
#  9815,
#  4989,
#  1724,
#  1477,
#  151,
#  1649,
#  7851,
#  3003,
#  6294,
#  8449,
#  2564,
#  9513,
#  6569,
#  2186,
#  4835,
#  127,
#  1152,
#  92,
#  1108,
#  5810,
#  3652,
#  8276,
#  2530,
#  2047,
#  988,
#  9352,
#  6811,
#  6760,
#  4556,
#  8895,
#  4379,
#  3901,
#  3128,
#  354,
#  5486,
#  7165,
#  4678,
#  5470,
#  4126,
#  2357,
#  2991,
#  873,
#  9384,
#  4834,
#  1078,
#  5939,
#  2410,
#  3585,
#  3740,
#  2970,
#  7301,
#  1965,
#  3695,
#  5870,
#  46,
#  2086,
#  4537,
#  4970,
#  4859,
#  8318,
#  3075,
#  6118,
#  174,
#  5117,
#  8015,
#  7146,
#  8381,
#  474,
#  5632,
#  5103,
#  3101,
#  6087,
#  1071,
#  9369,
#  2511,
#  1065,
#  6043,
#  5242,
#  944,
#  4284,
#  9294,
#  5356,
#  8048,
#  1425,
#  320,
#  964,
#  5359,
#  5444,
#  2743,
#  3977,
#  7947,
#  3386,
#  2527,
#  581,
#  1663,
#  5102,
#  1862,
#  2737,
#  7939,
#  2002,
#  3920,
#  900,
#  7255,
#  7286,
#  8053,
#  7195,
#  6157,
#  3157,
#  2164,
#  1206,
#  6102,
#  5766,
#  8615,
#  7895,
#  6936,
#  6168,
#  7832,
#  3686,
#  8327,
#  2865,
#  2345,
#  5648,
#  2920,
#  5447,
#  4862,
#  2703,
#  7353,
#  6344,
#  3368,
#  798,
#  3365,
#  4701,
#  9106,
#  7511,
#  3390,
#  3615,
#  4267,
#  4910,
#  8954,
#  1824,
#  6220,
#  5321,
#  5031,
#  2119,
#  8269,
#  6496,
#  7439,
#  8480,
#  9829,
#  2878,
#  9521,
#  5656,
#  3333,
#  4502,
#  8068,
#  596,
#  4196,
#  6520,
#  1404,
#  2160,
#  3897,
#  7303,
#  7948,
#  3048,
#  5506,
#  203,
#  4794,
#  7646,
#  8291,
#  392,
#  5481,
#  6825,
#  7227,
#  3007,
#  2861,
#  9828,
#  3247,
#  7174,
#  9914,
#  4363,
#  6907,
#  2597,
#  8977,
#  5774,
#  6002,
#  8581,
#  3543,
#  8932,
#  9349,
#  1311,
#  8046,
#  3126,
#  4311,
#  9079,
#  5324,
#  7526,
#  7675,
#  7488,
#  1284,
#  2068,
#  8972,
#  8491,
#  4717,
#  4784,
#  1799,
#  7827,
#  4207,
#  7249,
#  2897,
#  5560,
#  3981,
#  786,
#  8131,
#  4400,
#  8937,
#  2046,
#  4471,
#  2476,
#  7653,
#  73,
#  4002,
#  4010,
#  7960,
#  7087,
#  2898,
#  4098,
#  7763,
#  5434,
#  804,
#  7568,
#  2089,
#  8508,
#  4238,
#  194,
#  2545,
#  2474,
#  953,
#  3462,
#  572,
#  8023,
#  4981,
#  6153,
#  7101,
#  1319,
#  6935,
#  2760,
#  8181,
#  7469,
#  8985,
#  2069,
#  1759,
#  4407,
#  6603,
#  105,
#  1613,
#  5690,
#  6067,
#  5614,
#  608,
#  5258,
#  4008,
#  8307,
#  9189,
#  2544,
#  618,
#  2691,
#  2367,
#  611,
#  5634,
#  601,
#  3012,
#  5564,
#  2288,
#  2789,
#  4829,
#  2546,
#  4070,
#  3682,
#  7817,
#  4035,
#  3322,
#  6759,
#  9674,
#  7807,
#  1523,
#  9925,
#  8958,
#  2251,
#  8509,
#  5963,
#  5662,
#  4131,
#  2590,
#  1604,
#  462,
#  9281,
#  9554,
#  1577,
#  213,
#  3072,
#  4560,
#  5835,
#  8842,
#  7175,
#  7915,
#  6335,
#  1403,
#  4808,
#  7000,
#  3401,
#  4109,
#  360,
#  6584,
#  3584,
#  104,
#  4325,
#  7572,
#  3756,
#  4343,
#  2736,
#  2,
#  8115,
#  4651,
#  3805,
#  994,
#  5201,
#  9650,
#  1713,
#  7370,
#  3024,
#  3658,
#  9924,
#  834,
#  173,
#  6643,
#  883,
#  9431,
#  4589,
#  6564,
#  5840,
#  2101,
#  7666,
#  3718,
#  7189,
#  4247,
#  9783,
#  2583,
#  8047,
#  9969,
#  1414,
#  8754,
#  2387,
#  7258,
#  8346,
#  9041,
#  5581,
#  9119,
#  6130,
#  2930,
#  6286,
#  3045,
#  8499,
#  4798,
#  5010,
#  5438,
#  8210,
#  4026,
#  8939,
#  9332,
#  7354,
#  3457,
#  838,
#  8257,
#  5748,
#  2603,
#  5846,
#  2104,
#  4598,
#  7377,
#  1800,
#  7843,
#  3836,
#  1841,
#  339,
#  8869,
#  971,
#  7288,
#  4364,
#  484,
#  8328,
#  6217,
#  9907,
#  4176,
#  5529,
#  6704,
#  1939,
#  6819,
#  5355,
#  2801,
#  7106,
#  8601,
#  1827,
#  4439,
#  7596,
#  7253,
#  7164,
#  9859,
#  5251,
#  3432,
#  3751,
#  4115,
#  7758,
#  7612,
#  2262,
#  9408,
#  3409,
#  9657,
#  2640,
#  5834,
#  9841,
#  9710,
#  9552,
#  8444,
#  740,
#  9052,
#  8826,
#  3328,
#  7710,
#  1337,
#  7158,
#  3988,
#  6649,
#  1530,
#  2683,
#  3115,
#  2952,
#  4047,
#  6199,
#  895,
#  9547,
#  452,
#  7107,
#  6302,
#  1944,
#  7138,
#  3863,
#  1567,
#  2489,
#  6642,
#  1445,
#  3070,
#  8128,
#  1450,
#  4383,
#  940,
#  7790,
#  7896,
#  2605,
#  7583,
#  1598,
#  459,
#  3221,
#  7037,
#  9197,
#  1639,
#  5513,
#  5454,
#  8764,
#  3713,
#  6099,
#  9846,
#  2510,
#  7966,
#  1962,
#  2567,
#  1636,
#  4112,
#  5702,
#  1902,
#  5319,
#  8332,
#  7638,
#  3529,
#  8301,
#  3242,
#  7065,
#  7500,
#  9388,
#  438,
#  2911,
#  9475,
#  2944,
#  8075,
#  9326,
#  6132,
#  2272,
#  9171,
#  4866,
#  9152,
#  8864,
#  1554,
#  9806,
#  1067,
#  369,
#  1933,
#  3408,
#  3956,
#  9460,
#  9411,
#  4274,
#  9483,
#  1970,
#  4237,
#  7081,
#  9129,
#  410,
#  8687,
#  9135,
#  7213,
#  6167,
#  2334,
#  8147,
#  5982,
#  7845,
#  433,
#  6110,
#  3619,
#  ...]

# %%
mergesort(new_rand)
# Out:
# [0,
#  2,
#  4,
#  6,
#  8,
#  9,
#  12,
#  13,
#  15,
#  17,
#  18,
#  20,
#  21,
#  26,
#  32,
#  35,
#  37,
#  38,
#  39,
#  46,
#  47,
#  48,
#  50,
#  53,
#  55,
#  56,
#  57,
#  58,
#  60,
#  63,
#  64,
#  70,
#  73,
#  75,
#  77,
#  79,
#  81,
#  84,
#  89,
#  90,
#  91,
#  92,
#  93,
#  94,
#  97,
#  98,
#  99,
#  103,
#  104,
#  105,
#  109,
#  112,
#  117,
#  120,
#  121,
#  124,
#  125,
#  126,
#  127,
#  128,
#  129,
#  131,
#  137,
#  141,
#  142,
#  143,
#  148,
#  149,
#  151,
#  153,
#  156,
#  158,
#  160,
#  162,
#  164,
#  166,
#  169,
#  170,
#  172,
#  173,
#  174,
#  178,
#  181,
#  182,
#  186,
#  189,
#  192,
#  194,
#  195,
#  198,
#  201,
#  202,
#  203,
#  208,
#  209,
#  211,
#  212,
#  213,
#  215,
#  216,
#  219,
#  221,
#  223,
#  226,
#  228,
#  231,
#  232,
#  236,
#  239,
#  240,
#  244,
#  246,
#  247,
#  249,
#  253,
#  255,
#  258,
#  263,
#  266,
#  267,
#  271,
#  272,
#  274,
#  275,
#  276,
#  278,
#  279,
#  280,
#  281,
#  282,
#  286,
#  287,
#  292,
#  295,
#  296,
#  298,
#  299,
#  300,
#  303,
#  304,
#  305,
#  306,
#  308,
#  311,
#  313,
#  314,
#  316,
#  317,
#  319,
#  320,
#  322,
#  323,
#  324,
#  327,
#  328,
#  330,
#  333,
#  334,
#  336,
#  337,
#  339,
#  342,
#  344,
#  348,
#  350,
#  352,
#  354,
#  355,
#  358,
#  359,
#  360,
#  362,
#  363,
#  367,
#  369,
#  374,
#  375,
#  376,
#  379,
#  383,
#  385,
#  386,
#  387,
#  391,
#  392,
#  396,
#  399,
#  400,
#  401,
#  402,
#  403,
#  405,
#  409,
#  410,
#  418,
#  419,
#  424,
#  425,
#  427,
#  428,
#  429,
#  430,
#  431,
#  432,
#  433,
#  434,
#  435,
#  437,
#  438,
#  440,
#  442,
#  443,
#  446,
#  447,
#  448,
#  449,
#  450,
#  451,
#  452,
#  454,
#  455,
#  456,
#  457,
#  459,
#  460,
#  462,
#  463,
#  466,
#  469,
#  471,
#  472,
#  474,
#  476,
#  479,
#  481,
#  482,
#  483,
#  484,
#  485,
#  486,
#  492,
#  495,
#  500,
#  501,
#  503,
#  505,
#  506,
#  508,
#  509,
#  510,
#  517,
#  520,
#  524,
#  529,
#  530,
#  531,
#  534,
#  535,
#  536,
#  538,
#  540,
#  541,
#  542,
#  546,
#  548,
#  549,
#  550,
#  551,
#  553,
#  557,
#  560,
#  563,
#  564,
#  567,
#  570,
#  572,
#  574,
#  575,
#  577,
#  578,
#  581,
#  585,
#  587,
#  588,
#  589,
#  590,
#  593,
#  594,
#  596,
#  601,
#  603,
#  604,
#  606,
#  607,
#  608,
#  610,
#  611,
#  613,
#  614,
#  615,
#  616,
#  617,
#  618,
#  621,
#  622,
#  623,
#  627,
#  630,
#  631,
#  632,
#  634,
#  636,
#  643,
#  647,
#  648,
#  650,
#  659,
#  663,
#  665,
#  666,
#  669,
#  671,
#  673,
#  674,
#  675,
#  682,
#  683,
#  684,
#  685,
#  689,
#  690,
#  691,
#  692,
#  698,
#  700,
#  703,
#  704,
#  707,
#  708,
#  709,
#  711,
#  712,
#  715,
#  721,
#  722,
#  723,
#  724,
#  725,
#  727,
#  728,
#  730,
#  732,
#  734,
#  736,
#  737,
#  739,
#  740,
#  744,
#  751,
#  752,
#  753,
#  758,
#  761,
#  767,
#  768,
#  769,
#  770,
#  772,
#  774,
#  776,
#  778,
#  779,
#  782,
#  786,
#  787,
#  788,
#  789,
#  793,
#  794,
#  796,
#  797,
#  798,
#  800,
#  802,
#  804,
#  805,
#  808,
#  809,
#  823,
#  825,
#  826,
#  828,
#  830,
#  832,
#  833,
#  834,
#  835,
#  836,
#  837,
#  838,
#  841,
#  842,
#  844,
#  849,
#  852,
#  854,
#  858,
#  862,
#  865,
#  868,
#  869,
#  870,
#  871,
#  873,
#  874,
#  876,
#  880,
#  882,
#  883,
#  884,
#  885,
#  886,
#  887,
#  888,
#  889,
#  890,
#  891,
#  894,
#  895,
#  898,
#  899,
#  900,
#  901,
#  904,
#  905,
#  906,
#  907,
#  908,
#  911,
#  912,
#  916,
#  923,
#  928,
#  936,
#  940,
#  941,
#  944,
#  945,
#  946,
#  947,
#  948,
#  952,
#  953,
#  954,
#  955,
#  956,
#  959,
#  962,
#  963,
#  964,
#  965,
#  966,
#  971,
#  975,
#  977,
#  978,
#  979,
#  983,
#  985,
#  986,
#  988,
#  991,
#  992,
#  994,
#  996,
#  997,
#  998,
#  999,
#  1000,
#  1001,
#  1004,
#  1006,
#  1008,
#  1012,
#  1013,
#  1017,
#  1018,
#  1019,
#  1022,
#  1025,
#  1027,
#  1028,
#  1031,
#  1033,
#  1036,
#  1038,
#  1042,
#  1043,
#  1050,
#  1052,
#  1054,
#  1055,
#  1056,
#  1057,
#  1058,
#  1061,
#  1064,
#  1065,
#  1066,
#  1067,
#  1071,
#  1072,
#  1073,
#  1076,
#  1077,
#  1078,
#  1079,
#  1081,
#  1082,
#  1083,
#  1084,
#  1085,
#  1086,
#  1088,
#  1090,
#  1093,
#  1095,
#  1097,
#  1101,
#  1104,
#  1105,
#  1107,
#  1108,
#  1109,
#  1111,
#  1115,
#  1119,
#  1120,
#  1125,
#  1126,
#  1130,
#  1132,
#  1134,
#  1137,
#  1138,
#  1139,
#  1141,
#  1142,
#  1145,
#  1146,
#  1147,
#  1150,
#  1151,
#  1152,
#  1153,
#  1155,
#  1156,
#  1161,
#  1162,
#  1164,
#  1165,
#  1167,
#  1168,
#  1169,
#  1170,
#  1171,
#  1175,
#  1177,
#  1178,
#  1181,
#  1182,
#  1183,
#  1184,
#  1188,
#  1189,
#  1191,
#  1193,
#  1195,
#  1196,
#  1197,
#  1199,
#  1201,
#  1206,
#  1207,
#  1208,
#  1213,
#  1214,
#  1216,
#  1217,
#  1219,
#  1221,
#  1222,
#  1223,
#  1224,
#  1227,
#  1228,
#  1231,
#  1233,
#  1234,
#  1235,
#  1237,
#  1239,
#  1241,
#  1242,
#  1248,
#  1251,
#  1252,
#  1254,
#  1256,
#  1257,
#  1262,
#  1264,
#  1266,
#  1268,
#  1269,
#  1273,
#  1275,
#  1277,
#  1278,
#  1280,
#  1281,
#  1282,
#  1283,
#  1284,
#  1286,
#  1287,
#  1288,
#  1295,
#  1296,
#  1299,
#  1302,
#  1303,
#  1306,
#  1308,
#  1309,
#  1310,
#  1311,
#  1314,
#  1315,
#  1316,
#  1319,
#  1326,
#  1328,
#  1330,
#  1331,
#  1335,
#  1337,
#  1338,
#  1340,
#  1343,
#  1345,
#  1347,
#  1348,
#  1351,
#  1352,
#  1361,
#  1362,
#  1369,
#  1371,
#  1372,
#  1373,
#  1374,
#  1375,
#  1376,
#  1379,
#  1380,
#  1381,
#  1384,
#  1387,
#  1388,
#  1389,
#  1397,
#  1398,
#  1399,
#  1400,
#  1402,
#  1403,
#  1404,
#  1406,
#  1410,
#  1411,
#  1413,
#  1414,
#  1418,
#  1419,
#  1420,
#  1422,
#  1424,
#  1425,
#  1428,
#  1429,
#  1430,
#  1431,
#  1433,
#  1434,
#  1440,
#  1443,
#  1444,
#  1445,
#  1447,
#  1448,
#  1449,
#  1450,
#  1451,
#  1452,
#  1453,
#  1461,
#  1462,
#  1463,
#  1464,
#  1465,
#  1466,
#  1468,
#  1469,
#  1470,
#  1471,
#  1473,
#  1477,
#  1478,
#  1479,
#  1480,
#  1482,
#  1487,
#  1490,
#  1491,
#  1492,
#  1494,
#  1496,
#  1497,
#  1498,
#  1499,
#  1501,
#  1502,
#  1506,
#  1510,
#  1513,
#  1517,
#  1523,
#  1524,
#  1526,
#  1528,
#  1529,
#  1530,
#  1531,
#  1534,
#  1535,
#  1536,
#  1537,
#  1541,
#  1542,
#  1543,
#  1546,
#  1549,
#  1550,
#  1551,
#  1554,
#  1556,
#  1566,
#  1567,
#  1569,
#  1570,
#  1571,
#  1575,
#  1576,
#  1577,
#  1579,
#  1580,
#  1583,
#  1584,
#  1585,
#  1592,
#  1596,
#  1597,
#  1598,
#  1600,
#  1601,
#  1603,
#  1604,
#  1607,
#  1608,
#  1609,
#  1612,
#  1613,
#  1614,
#  1616,
#  1617,
#  1618,
#  1619,
#  1622,
#  1623,
#  1631,
#  1632,
#  1633,
#  1634,
#  1635,
#  1636,
#  1637,
#  1639,
#  1640,
#  1642,
#  1643,
#  1644,
#  1645,
#  1646,
#  1648,
#  1649,
#  1650,
#  1653,
#  1658,
#  1659,
#  1663,
#  1664,
#  1668,
#  1671,
#  1672,
#  1678,
#  1680,
#  1681,
#  1682,
#  1687,
#  1691,
#  1693,
#  1695,
#  1697,
#  1701,
#  1702,
#  1704,
#  1705,
#  1706,
#  1707,
#  1709,
#  1710,
#  1711,
#  1712,
#  1713,
#  1714,
#  1715,
#  1717,
#  1719,
#  1720,
#  1724,
#  1725,
#  1726,
#  1733,
#  1735,
#  1736,
#  1738,
#  1739,
#  1740,
#  1741,
#  1743,
#  1744,
#  1745,
#  1746,
#  1749,
#  1750,
#  1752,
#  1756,
#  1759,
#  1764,
#  1765,
#  1770,
#  1771,
#  1776,
#  1779,
#  1781,
#  1783,
#  1789,
#  1792,
#  1795,
#  1798,
#  1799,
#  1800,
#  1802,
#  1803,
#  1804,
#  1805,
#  1807,
#  1808,
#  1809,
#  1810,
#  1811,
#  1813,
#  1817,
#  1818,
#  1819,
#  1820,
#  1821,
#  1822,
#  1824,
#  1827,
#  1828,
#  1829,
#  1831,
#  1834,
#  1835,
#  1837,
#  1839,
#  1841,
#  1844,
#  1845,
#  1848,
#  1849,
#  1850,
#  1855,
#  1858,
#  1859,
#  1862,
#  1863,
#  1864,
#  1865,
#  1866,
#  1867,
#  1871,
#  1876,
#  1877,
#  1878,
#  1879,
#  1880,
#  1881,
#  1882,
#  1889,
#  1890,
#  1892,
#  1894,
#  1895,
#  1896,
#  1899,
#  1901,
#  1902,
#  1903,
#  1904,
#  1905,
#  1906,
#  1910,
#  1917,
#  1918,
#  1920,
#  1921,
#  1925,
#  1927,
#  1928,
#  1930,
#  1931,
#  1932,
#  1933,
#  1934,
#  1935,
#  1937,
#  1938,
#  1939,
#  1943,
#  1944,
#  1945,
#  1947,
#  1948,
#  1950,
#  1956,
#  1958,
#  1959,
#  1960,
#  1961,
#  1962,
#  1963,
#  1964,
#  1965,
#  1967,
#  1970,
#  1979,
#  1980,
#  1981,
#  1984,
#  1985,
#  1989,
#  1993,
#  1994,
#  1996,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2010,
#  2011,
#  2012,
#  2013,
#  2018,
#  2019,
#  2025,
#  2026,
#  2028,
#  2033,
#  2034,
#  2039,
#  2043,
#  2044,
#  2046,
#  2047,
#  2050,
#  ...]

# %% [markdown]
# ### Check out
# - K-way merge sort
# - Counting inversion in arrays
# - Merge sort and insertion sort hybrid
